# %%
from pathlib import Path
import zipfile

import kagglehub
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 30)
pd.set_option('display.width', 130)

DATASET_HANDLE = "datascikhan/e-commerce-sales-and-customer-analytics"

# Download the dataset and locate its first CSV file.
dataset_path = Path(kagglehub.dataset_download(DATASET_HANDLE))

if dataset_path.is_file() and zipfile.is_zipfile(dataset_path):
    with zipfile.ZipFile(dataset_path) as archive:
        csv_names = [name for name in archive.namelist() if name.lower().endswith(".csv")]
        if not csv_names:
            raise FileNotFoundError("No CSV file was found in the downloaded dataset.")
        csv_name = csv_names[0]
        with archive.open(csv_name) as csv_file:
            df_clientes = pd.read_csv(csv_files[0], sep=None, engine="python", encoding="utf-8")
            df_estatisticas = pd.read_csv(csv_files[1], sep=None, engine="python", encoding="utf-8")
            df_vendas = pd.read_csv(csv_files[2], sep=None, engine="python", encoding="utf-8")
            df_pedidos = pd.read_csv(csv_files[3], sep=None, engine="python", encoding="utf-8")
            df_catalogo = pd.read_csv(csv_files[4], sep=None, engine="python", encoding="utf-8")
else:
    csv_files = list(dataset_path.rglob("*.csv")) if dataset_path.is_dir() else [dataset_path]
    if not csv_files:
        raise FileNotFoundError("No CSV file was found in the downloaded dataset.")
    df_clientes = pd.read_csv(csv_files[0], sep=None, engine="python", encoding="utf-8")
    df_estatisticas = pd.read_csv(csv_files[1], sep=None, engine="python", encoding="utf-8")
    df_vendas = pd.read_csv(csv_files[2], sep=None, engine="python", encoding="utf-8")
    df_pedidos = pd.read_csv(csv_files[3], sep=None, engine="python", encoding="utf-8")
    df_catalogo = pd.read_csv(csv_files[4], sep=None, engine="python", encoding="utf-8")


print("Loaded file:", csv_name if "csv_name" in locals() else csv_files[0].name)
print("Loaded file:", csv_name if "csv_name" in locals() else csv_files[1].name)
print("Loaded file:", csv_name if "csv_name" in locals() else csv_files[2].name)
print("Loaded file:", csv_name if "csv_name" in locals() else csv_files[3].name)
print("Loaded file:", csv_name if "csv_name" in locals() else csv_files[4].name)
# Out:
# Loaded file: customer_master.csv
# Loaded file: dataset_statistics.csv
# Loaded file: ecommerce_sales_customer_analytics_150k.csv
# Loaded file: order_items.csv
# Loaded file: product_catalog.csv

# %%
display(df_clientes.head(5))
# Out:
#    customer_id customer_name  customer_age  gender customer_segment   customer_city customer_state customer_country region  \
# 0  CUST-000001  Donna Miller            54  Female         Consumer      Laurenland          Dubai              UAE  South
# 1  CUST-000002  Joseph James            61    Male         Consumer      Lake Peter   Lower Saxony          Germany  North
# 2  CUST-000003  Daniel Smith            47    Male         Consumer        Seanview    North Rhine          Germany   West
# 3  CUST-000004   David Lopez            30    Male              VIP    Hawkinshaven   Pennsylvania              USA   East
# 4  CUST-000005  Dakota Davis            55  Female         Consumer  New Carlymouth        Florida              USA  South
#
#    customer_postal_code  customer_acquisition_cost
# 0                 11253                      13.58
# 1                 47778                      27.45
# 2                 13900                      31.53
# ...

# %%
display(df_estatisticas)
# Out:
#    Total Transactions  Total Columns  Total Customers  Total Products Used                Date Range    Total Revenue  \
# 0              138116             46            24911               138116  2021-01-01 to 2025-12-31  $177,134,263.74
#
#      Total Profit Average Order Value  Average Rating Return Rate Cancellation Rate
# 0  $76,146,395.76           $1,282.50            3.68       6.85%             6.08%

# %%
display(df_vendas.head(5))
# Out:
#      order_id  order_date order_time order_status sales_channel  customer_id   customer_name  customer_age  gender  \
# 0  ORD-301242  2023-11-06   16:37:47    Completed    Mobile App  CUST-003102    Jasmine Ryan            55    Male
# 1  ORD-773460  2025-12-24   01:22:36    Completed       Website  CUST-003124     Scott Chase            26    Male
# 2  ORD-449374  2021-07-05   14:24:21    Completed    Mobile App  CUST-012496    Marc Wheeler            69  Female
# 3  ORD-567636  2023-01-21   07:20:26    Completed  Social Media  CUST-023928  Jennifer Smith            65    Male
# 4  ORD-820028  2022-05-13   09:46:21    Completed  Social Media  CUST-012730    Jessica Wang            34  Female
#
#   customer_segment customer_type     customer_city     customer_state customer_country region  ...  coupon_code  \
# 0         Consumer         Loyal  Lake Williamberg              Texas              USA  South  ...          NaN
# ...

# %%
display(df_pedidos.head(5))
# Out:
#      order_id   product_id  quantity  unit_price  discount_percentage  discount_amount  gross_sales  tax_amount  shipping_cost  \
# 0  ORD-301242  PROD-000738         2      244.40             0.339607           166.00       488.80       22.60           6.48
# 1  ORD-301242  PROD-000181         3      287.13             0.362076           311.89       861.39       38.47           5.55
# 2  ORD-773460  PROD-000973         4      754.80             0.468300          1413.89      3019.20      305.01           9.00
# 3  ORD-773460  PROD-000268         4       31.36             0.336182            42.17       125.44       15.82           0.00
# 4  ORD-449374  PROD-001040         3        6.31             0.089678             1.70        18.93        1.21           0.98
#
#    net_sales  product_cost  profit
# 0     351.88        173.28  172.12
# 1     593.52        415.05  172.92
# 2    1919.32       1976.16  -65.84
# 3      99.09         55.72   43.37
# ...

# %%
display(df_catalogo.head(5))
# Out:
#     product_id                                       product_name product_category product_subcategory    brand  \
# 0  PROD-000001    Apple Sharable bifurcated algorithm Smartphones      Electronics         Smartphones    Apple
# 1  PROD-000002  Google User-centric even-keeled encryption Sma...      Electronics         Smartphones   Google
# 2  PROD-000003  LG Face-to-face client-driven support Smartphones      Electronics         Smartphones       LG
# 3  PROD-000004  Sony Customer-focused systematic support Smart...      Electronics         Smartphones     Sony
# 4  PROD-000005  OnePlus Quality-focused background parallelism...      Electronics         Smartphones  OnePlus
#
#               supplier  unit_price  product_cost  product_rating
# 0              Alibaba      686.90        474.06             4.3
# 1       Euro Logistics      978.26        519.66             2.9
# 2  Asian Manufacturing      275.51        185.48             3.9
# ...
